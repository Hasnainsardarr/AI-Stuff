# %%
# You can also use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass


import warnings

warnings.warn = warn
warnings.filterwarnings("ignore")

from ibm_watsonx_ai.foundation_models import Model
from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
from ibm_watsonx_ai.foundation_models.utils.enums import ModelTypes
from ibm_watson_machine_learning.foundation_models.extensions.langchain import (
    WatsonxLLM,
)
from langchain_core.prompts import PromptTemplate
from langchain.chains import LLMChain
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 11
#       8 warnings.warn = warn
#       9 warnings.filterwarnings("ignore")
# ---> 11 from ibm_watsonx_ai.foundation_models import Model
#      12 from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
#      13 from ibm_watsonx_ai.foundation_models.utils.enums import ModelTypes
#
# ModuleNotFoundError: No module named 'ibm_watsonx_ai'

# %%
# !pip install --user ibm-watsonx-ai
# Out:
# Collecting ibm-watsonx-ai
#   Downloading ibm_watsonx_ai-1.3.34-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: requests in c:\users\uae\appdata\roaming\python\python313\site-packages (from ibm-watsonx-ai) (2.32.5)
# Requirement already satisfied: httpx<0.29,>=0.27 in c:\users\uae\appdata\roaming\python\python313\site-packages (from ibm-watsonx-ai) (0.28.1)
# Requirement already satisfied: urllib3 in c:\users\uae\appdata\roaming\python\python313\site-packages (from ibm-watsonx-ai) (2.3.0)
# Requirement already satisfied: pandas<2.3.0,>=0.24.2 in c:\users\uae\appdata\roaming\python\python313\site-packages (from ibm-watsonx-ai) (2.2.3)
# Requirement already satisfied: certifi in c:\users\uae\appdata\roaming\python\python313\site-packages (from ibm-watsonx-ai) (2025.1.31)
# Collecting lomond (from ibm-watsonx-ai)
#   Downloading lomond-0.3.3-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting tabulate (from ibm-watsonx-ai)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: packaging in c:\users\uae\appdata\roaming\python\python313\site-packages (from ibm-watsonx-ai) (24.2)
# Collecting ibm-cos-sdk<2.15.0,>=2.12.0 (from ibm-watsonx-ai)
#   Downloading ibm_cos_sdk-2.14.3.tar.gz (58 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: cachetools in c:\users\uae\appdata\roaming\python\python313\site-packages (from ibm-watsonx-ai) (5.5.2)
# Requirement already satisfied: anyio in c:\users\uae\appdata\roaming\python\python313\site-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\uae\appdata\roaming\python\python313\site-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai) (1.0.9)
# Requirement already satisfied: idna in c:\users\uae\appdata\roaming\python\python313\site-packages (from httpx<0.29,>=0.27->ibm-watsonx-ai) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\uae\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx<0.29,>=0.27->ibm-watsonx-ai) (0.16.0)
# Collecting ibm-cos-sdk-core==2.14.3 (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai)
#   Downloading ibm_cos_sdk_core-2.14.3.tar.gz (1.1 MB)
#      ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#      ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#      --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#      --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#      --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#      --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#      --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#      ------------------- -------------------- 0.5/1.1 MB 240.3 kB/s eta 0:00:03
#      ------------------- -------------------- 0.5/1.1 MB 240.3 kB/s eta 0:00:03
#      ------------------- -------------------- 0.5/1.1 MB 240.3 kB/s eta 0:00:03
#      ---------------------------- ----------- 0.8/1.1 MB 289.1 kB/s eta 0:00:02
#      ---------------------------- ----------- 0.8/1.1 MB 289.1 kB/s eta 0:00:02
#      ---------------------------- ----------- 0.8/1.1 MB 289.1 kB/s eta 0:00:02
#      ---------------------------- ----------- 0.8/1.1 MB 289.1 kB/s eta 0:00:02
#      -------------------------------------- - 1.0/1.1 MB 301.5 kB/s eta 0:00:01
#      ---------------------------------------- 1.1/1.1 MB 300.9 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting ibm-cos-sdk-s3transfer==2.14.3 (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai)
#   Downloading ibm_cos_sdk_s3transfer-2.14.3.tar.gz (139 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting jmespath<=1.0.1,>=0.10.0 (from ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0 in c:\users\uae\appdata\roaming\python\python313\site-packages (from ibm-cos-sdk-core==2.14.3->ibm-cos-sdk<2.15.0,>=2.12.0->ibm-watsonx-ai) (2.9.0.post0)
# Collecting urllib3 (from ibm-watsonx-ai)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\uae\appdata\roaming\python\python313\site-packages (from pandas<2.3.0,>=0.24.2->ibm-watsonx-ai) (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\uae\appdata\roaming\python\python313\site-packages (from pandas<2.3.0,>=0.24.2->ibm-watsonx-ai) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\uae\appdata\roaming\python\python313\site-packages (from pandas<2.3.0,>=0.24.2->ibm-watsonx-ai) (2025.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\uae\appdata\roaming\python\python313\site-packages (from requests->ibm-watsonx-ai) (3.4.1)
# Requirement already satisfied: six>=1.10.0 in c:\users\uae\appdata\roaming\python\python313\site-packages (from lomond->ibm-watsonx-ai) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\uae\appdata\roaming\python\python313\site-packages (from anyio->httpx<0.29,>=0.27->ibm-watsonx-ai) (1.3.1)
# Downloading ibm_watsonx_ai-1.3.34-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.2 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.2 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.2 MB ? eta -:--:--
#    ----------------- ---------------------- 0.5/1.2 MB 379.2 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.5/1.2 MB 379.2 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.5/1.2 MB 379.2 kB/s eta 0:00:02
#    -------------------------- ------------- 0.8/1.2 MB 386.0 kB/s eta 0:00:02
#    -------------------------- ------------- 0.8/1.2 MB 386.0 kB/s eta 0:00:02
#    -------------------------- ------------- 0.8/1.2 MB 386.0 kB/s eta 0:00:02
#    -------------------------- ------------- 0.8/1.2 MB 386.0 kB/s eta 0:00:02
#    ----------------------------------- ---- 1.0/1.2 MB 391.5 kB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 390.9 kB/s eta 0:00:00
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading lomond-0.3.3-py2.py3-none-any.whl (35 kB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Building wheels for collected packages: ibm-cos-sdk, ibm-cos-sdk-core, ibm-cos-sdk-s3transfer
#   Building wheel for ibm-cos-sdk (pyproject.toml): started
#   Building wheel for ibm-cos-sdk (pyproject.toml): finished with status 'done'
#   Created wheel for ibm-cos-sdk: filename=ibm_cos_sdk-2.14.3-py3-none-any.whl size=77349 sha256=7844e53c7e04f8cf63796ee66e6af52568b133db45e50eeb212ce63176f6a884
#   Stored in directory: c:\users\uae\appdata\local\pip\cache\wheels\a2\99\26\abae30f0704d74b848aac9aac73e9b47977b808a75a5a984fe
#   Building wheel for ibm-cos-sdk-core (pyproject.toml): started
#   Building wheel for ibm-cos-sdk-core (pyproject.toml): finished with status 'done'
#   Created wheel for ibm-cos-sdk-core: filename=ibm_cos_sdk_core-2.14.3-py3-none-any.whl size=662220 sha256=ad98c18a5ca2ee046ad98388f188b34d9ecb7ece6690c404542f95c7f78703af
#   Stored in directory: c:\users\uae\appdata\local\pip\cache\wheels\47\62\69\1e99fea95b82e8dbd4ea97e78160224269774a43883f908551
#   Building wheel for ibm-cos-sdk-s3transfer (pyproject.toml): started
#   Building wheel for ibm-cos-sdk-s3transfer (pyproject.toml): finished with status 'done'
#   Created wheel for ibm-cos-sdk-s3transfer: filename=ibm_cos_sdk_s3transfer-2.14.3-py3-none-any.whl size=90320 sha256=4d172934b2c94b3ecc3fdf923941d8a8a8ab31852040ae3fe0bacd0857e6b75d
#   Stored in directory: c:\users\uae\appdata\local\pip\cache\wheels\a4\41\53\4fdc180f2fe8bd53f98fd46d071708bfa93db0339af2ebd6ad
# Successfully built ibm-cos-sdk ibm-cos-sdk-core ibm-cos-sdk-s3transfer
# Installing collected packages: urllib3, tabulate, lomond, jmespath, ibm-cos-sdk-core, ibm-cos-sdk-s3transfer, ibm-cos-sdk, ibm-watsonx-ai
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.3.0
#     Uninstalling urllib3-2.3.0:
#       Successfully uninstalled urllib3-2.3.0
# Successfully installed ibm-cos-sdk-2.14.3 ibm-cos-sdk-core-2.14.3 ibm-cos-sdk-s3transfer-2.14.3 ibm-watsonx-ai-1.3.34 jmespath-1.0.1 lomond-0.3.3 tabulate-0.9.0 urllib3-2.5.0
#   WARNING: The script tabulate.exe is installed in 'C:\Users\UAE\AppData\Roaming\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# You can also use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass


import warnings

warnings.warn = warn
warnings.filterwarnings("ignore")

from ibm_watsonx_ai.foundation_models import Model
from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
from ibm_watsonx_ai.foundation_models.utils.enums import ModelTypes
from ibm_watson_machine_learning.foundation_models.extensions.langchain import (
    WatsonxLLM,
)
from langchain_core.prompts import PromptTemplate
from langchain.chains import LLMChain
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 11
#       8 warnings.warn = warn
#       9 warnings.filterwarnings("ignore")
# ---> 11 from ibm_watsonx_ai.foundation_models import Model
#      12 from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
#      13 from ibm_watsonx_ai.foundation_models.utils.enums import ModelTypes
#
# ModuleNotFoundError: No module named 'ibm_watsonx_ai'

# %%
# You can also use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass


import warnings

warnings.warn = warn
warnings.filterwarnings("ignore")

from ibm_watsonx_ai.foundation_models import Model
from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
from ibm_watsonx_ai.foundation_models.utils.enums import ModelTypes
from ibm_watson_machine_learning.foundation_models.extensions.langchain import (
    WatsonxLLM,
)
from langchain_core.prompts import PromptTemplate
from langchain.chains import LLMChain
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 11
#       8 warnings.warn = warn
#       9 warnings.filterwarnings("ignore")
# ---> 11 from ibm_watsonx_ai.foundation_models import Model
#      12 from ibm_watsonx_ai.metanames import GenTextParamsMetaNames as GenParams
#      13 from ibm_watsonx_ai.foundation_models.utils.enums import ModelTypes
#
# ModuleNotFoundError: No module named 'ibm_watsonx_ai'
